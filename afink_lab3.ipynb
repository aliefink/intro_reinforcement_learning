# %% [markdown]
# Please start by making your own copy of this Google Colab notebook.
#
# Learning objectives:
#
# * Implement TDRL agent
# * Generate and visualize predicted neural activity from TDRL
# * Modify TDRL agent and discuss how this changes neural predictions
#
# The cell below imports some necessary modules:

# %%
import numpy as np  
from scipy.stats import norm

import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Define environment

# %%
class SingleTrack(object):
  
  """Class for the single track environment.

  Parameters
  ----------
  n_states : int
      Number of states on the track.
  
  """

  def __init__(self, n_states):

    self.n_states = n_states          
    self.states = np.arange(0, n_states)
    self.reward_location = self.n_states
    
  def visualize(self):

    print("Green is the goal state... ")

    xs = np.arange(0, self.n_states+1, 1)
    ys = np.arange(0, 2)

    fig, ax = plt.subplots(1, 1, figsize=(self.n_states,1))
    # grid "shades" (boxes)
    w, h = xs[1] - xs[0], ys[1] - ys[0]
    for i, x in enumerate(xs[:-1]):
        for j, y in enumerate(ys[:-1]):
            if (i == self.reward_location - 1):            
                ax.add_patch(Rectangle((x, y), w, h, fill=True, color='#008610', alpha=.1))
    # grid lines
    for x in xs:
        plt.plot([x, x], [ys[0], ys[-1]], color='black', alpha=.33, linestyle=':')
    for y in ys:
        plt.plot([xs[0], xs[-1]], [y, y], color='black', alpha=.33, linestyle=':')
    
    ax.set_xticks(xs[:-1]+0.5)
    ax.set_xticklabels(xs[:-1]+1)
    ax.set_yticklabels([])
    ax.set_xlabel('State', fontsize=15)

    plt.tick_params(left = False)
    plt.show()

# %%
track = SingleTrack(10)
track.visualize()
# Out:
# Green is the goal state...

# %% [markdown]
# # Define agent

# %%
class TDRL(object):
  """Class for the TDRL reward prediction algorithm. 

  Parameters
  ----------

  alpha : float, range (0, 1)
      Learning rate.

  gamma : float, range (0, 1)
      Discount factor.

  """

  def __init__(self, env, alpha, gamma, v_init = False):

    self.a = alpha
    self.g = gamma

    # initialize values
    if v_init: # check if initial values were provided 
      self.v = np.ones((env.n_states, ))*v_init     
    else:   
      self.v = np.zeros((env.n_states, ))

    # initialize td-errors
    self.d = np.zeros((env.n_states, ))

  def update(self, current_state, new_state, reward, verbose=False):

    td_error = reward + self.g * self.v[new_state-1] - self.v[current_state-1]

    print('delta: ' + str(td_error))

    self.d[current_state] = td_error
    self.v[current_state-1] = self.v[current_state-1] + self.a * td_error

    if verbose == True: 
      print(self.v)

# %%
def run_simulation(params, n_episodes):

  """Function for running a simulation of TDRL in the single track environment."""

  # make environment
  env = SingleTrack(params['n_states'])

  # initialize agent 
  agent = TDRL(env, params['alpha'], params['gamma'])

  # initialize output containers
  V = []
  D = []

  V = np.zeros((n_episodes, params['n_states']))
  D = np.zeros((n_episodes, params['n_states']))

  for e in np.arange(n_episodes):

    print("Ran the track " + str(e) + " times so far") 

    for s in np.arange(params['n_states']):

      current_state = s+1
      print('current state: ' + str(current_state))
      print('moving left...')
      new_state = current_state+1

      # get reward at the end of track.
      if (new_state == env.reward_location):
          reward = 10
      else: 
          reward = 0;

      print('reward: ' + str(reward))
      print('new state: ' + str(new_state))

      agent.update(current_state, new_state, reward)
      
      # check if we reached the end of the track
      is_terminal = (new_state == params['n_states'])
      if is_terminal:
          
          V[e,:] = agent.v
          D[e,:] = agent.d
         
          print('We reached the end')
        
          break

  return env, V, D

# %% [markdown]
# # Run track simulation

# %%
n_episodes = 10

params = {
    'n_states': 10,
    'alpha': 0.2,
    'gamma': 0.9
}

env, V, D = run_simulation(params, n_episodes)
# Out:
# Ran the track 0 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 10.0
# We reached the end
# Ran the track 1 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 1.8
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 8.0
# We reached the end
# Ran the track 2 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.32400000000000007
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 2.8800000000000003
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 6.4
# We reached the end
# Ran the track 3 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.05832000000000001
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.7776000000000002
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 3.4560000000000013
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 5.119999999999999
# We reached the end
# Ran the track 4 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.010497600000000003
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.18662400000000007
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 1.2441600000000004
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 3.686400000000001
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 4.095999999999999
# We reached the end
# Ran the track 5 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0018895680000000005
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.04199040000000001
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.37324800000000014
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 1.6588800000000004
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 3.6864
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 3.2767999999999997
# We reached the end
# Ran the track 6 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0003401222400000001
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.009069926400000003
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.10077696000000003
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.5971968000000002
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 1.9906560000000004
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 3.538944
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 2.6214399999999998
# We reached the end
# Ran the track 7 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 6.122200320000003e-05
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0019046845440000004
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.02539579392000001
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.18811699200000007
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.8360755200000003
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 2.22953472
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 3.3030144
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 2.0971519999999995
# We reached the end
# Ran the track 8 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 1.1019960576000006e-05
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0003918208204800001
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.006094990540800003
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.05417769369600002
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.30098718720000006
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 1.0701766656000002
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 2.378170368
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 3.0198988799999995
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 1.6777216
# We reached the end
# Ran the track 9 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 7.934371614720002e-05
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0014105549537280007
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.014627977297920008
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.09751984865280003
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.43342154956800016
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 1.28421199872
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 2.4461180928000004
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 2.717908992
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 1.3421772799999996
# We reached the end

# %% [markdown]
# # Visualize results

# %%
# Value
df_wide = pd.DataFrame(V.T)
df_wide.loc[len(df_wide.index)-1] = 10

fig, ax = plt.subplots(1,1,figsize=(9,4))
sns.lineplot(data=df_wide, legend=True, palette='Blues', markers=True, dashes=False)
ax.legend(labels=list(np.arange(params['n_states'])+1))
ax.axvline(x=params['n_states']-1, color='blue',linewidth=4)
ax.set_xticks(np.arange(params['n_states']))
labels = [str(i) for i in np.arange(params['n_states'])+1]
labels[-1] = 'R'
ax.set_xticklabels(labels)
ax.set_xlabel('State',fontsize=15);
ax.set_ylabel('Value',fontsize=15);
sns.set_style('white');
sns.despine();

# TD-error
df_wide = pd.DataFrame(D.T)

fig, ax = plt.subplots(1,1,figsize=(9,4))
sns.lineplot(data=df_wide, legend=True, palette='Greens', markers=True, dashes=False)
ax.legend(labels=list(np.arange(params['n_states'])+1))
ax.axvline(x=params['n_states']-1, color='green',linewidth=4)
ax.set_xticks(np.arange(params['n_states']))
labels = [str(i) for i in np.arange(params['n_states'])+1]
labels[-1] = 'R'
ax.set_xticklabels(labels)
ax.set_xlabel('State',fontsize=15);
ax.set_ylabel('Temporal-Difference error',fontsize=15);
sns.set_style('white');
sns.despine();

env.visualize()
# Out:
# Green is the goal state...

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Question 1
# 1.   Based on the simulation above, after how many episodes would we expect to see TD-error related activity in dopamine neurons when the mouse reaches state 10? What about state 8? Briefly explain.
# - episode 1
# - episode ~3

# %% [markdown]
# ## Question 2
# One way we can describe what TD-Learning does is that the value of the reward “propagates backwards” to previous states. That is, each state preceding the goal state acquires a little bit of predictive value. Modify the simulation to check after how many episodes the reward becomes fully predicted.
#
# Tried 20, 50, 100:
# - at 20 - becomes fully predicted at 7
# - at 50 - becomes fully predicted at 2
# - by 70 episodes the first state fully predicts the reward! (the error line has no slope)

# %% [markdown]
# ## Question 3
# Based on the simulation, implement a Rescorla-Wagner agent (hint: you will only need to change one parameter). How do your answers to Question 1 change under this model?
#
# - make gamma term zero because rescorla wagner does not discount
#
# Difference from question 1:
# - In the rescorla wagner model the reward signal does not back propogate so the 'TD error' will always occur at state 9 right before the reward. This is when the TD neurons will always spike.
# - After 10 episodes the value at state 8 becomes higher, after increasing the number of episodes to 10, this value does not change.
# - Rescorla wagner improves less with greater episodes. The gamma error term shows that the TD model improves prediction of reward in earlier states.

# %%
n_episodes = 50

params = {
    'n_states': 10,
    'alpha': 0.2,
    'gamma': 0
}

env, V, D = run_simulation(params, n_episodes)
# Out:
# Ran the track 0 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 10.0
# We reached the end
# Ran the track 1 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 8.0
# We reached the end
# Ran the track 2 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 6.4
# We reached the end
# Ran the track 3 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 5.119999999999999
# We reached the end
# Ran the track 4 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 4.095999999999999
# We reached the end
# Ran the track 5 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 3.2767999999999997
# We reached the end
# Ran the track 6 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 2.6214399999999998
# We reached the end
# Ran the track 7 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 2.0971519999999995
# We reached the end
# Ran the track 8 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 1.6777216
# We reached the end
# Ran the track 9 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 1.3421772799999996
# We reached the end
# Ran the track 10 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 1.073741823999999
# We reached the end
# Ran the track 11 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.8589934591999988
# We reached the end
# Ran the track 12 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.6871947673599994
# We reached the end
# Ran the track 13 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.5497558138879999
# We reached the end
# Ran the track 14 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.4398046511103999
# We reached the end
# Ran the track 15 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.3518437208883203
# We reached the end
# Ran the track 16 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.2814749767106566
# We reached the end
# Ran the track 17 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.2251799813685249
# We reached the end
# Ran the track 18 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.18014398509481921
# We reached the end
# Ran the track 19 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.14411518807585466
# We reached the end
# Ran the track 20 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.11529215046068408
# We reached the end
# Ran the track 21 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.09223372036854727
# We reached the end
# Ran the track 22 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.0737869762948371
# We reached the end
# Ran the track 23 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.05902958103586897
# We reached the end
# Ran the track 24 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.04722366482869589
# We reached the end
# Ran the track 25 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.037778931862956
# We reached the end
# Ran the track 26 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.03022314549036409
# We reached the end
# Ran the track 27 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.024178516392291627
# We reached the end
# Ran the track 28 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.019342813113834012
# We reached the end
# Ran the track 29 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.01547425049106721
# We reached the end
# Ran the track 30 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.012379400392854123
# We reached the end
# Ran the track 31 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.009903520314283654
# We reached the end
# Ran the track 32 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.007922816251426212
# We reached the end
# Ran the track 33 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.006338253001141325
# We reached the end
# Ran the track 34 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.00507060240091306
# We reached the end
# Ran the track 35 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.004056481920731159
# We reached the end
# Ran the track 36 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.003245185536584927
# We reached the end
# Ran the track 37 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.0025961484292675863
# We reached the end
# Ran the track 38 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.0020769187434144243
# We reached the end
# Ran the track 39 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.0016615349947315394
# We reached the end
# Ran the track 40 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.001329227995785942
# We reached the end
# Ran the track 41 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.0010633823966283984
# We reached the end
# Ran the track 42 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.000850705917303074
# We reached the end
# Ran the track 43 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.0006805647338428145
# We reached the end
# Ran the track 44 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.0005444517870749621
# We reached the end
# Ran the track 45 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.0004355614296596144
# We reached the end
# Ran the track 46 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.00034844914372733626
# We reached the end
# Ran the track 47 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.0002787593149822243
# We reached the end
# Ran the track 48 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.00022300745198577943
# We reached the end
# Ran the track 49 times so far
# current state: 1
# moving left...
# reward: 0
# new state: 2
# delta: 0.0
# current state: 2
# moving left...
# reward: 0
# new state: 3
# delta: 0.0
# current state: 3
# moving left...
# reward: 0
# new state: 4
# delta: 0.0
# current state: 4
# moving left...
# reward: 0
# new state: 5
# delta: 0.0
# current state: 5
# moving left...
# reward: 0
# new state: 6
# delta: 0.0
# current state: 6
# moving left...
# reward: 0
# new state: 7
# delta: 0.0
# current state: 7
# moving left...
# reward: 0
# new state: 8
# delta: 0.0
# current state: 8
# moving left...
# reward: 0
# new state: 9
# delta: 0.0
# current state: 9
# moving left...
# reward: 10
# new state: 10
# delta: 0.000178405961587913
# We reached the end

# %%
# Value
df_wide = pd.DataFrame(V.T)
df_wide.loc[len(df_wide.index)-1] = 10

fig, ax = plt.subplots(1,1,figsize=(9,4))
sns.lineplot(data=df_wide, legend=True, palette='Blues', markers=True, dashes=False)
ax.legend(labels=list(np.arange(params['n_states'])+1))
ax.axvline(x=params['n_states']-1, color='blue',linewidth=4)
ax.set_xticks(np.arange(params['n_states']))
labels = [str(i) for i in np.arange(params['n_states'])+1]
labels[-1] = 'R'
ax.set_xticklabels(labels)
ax.set_xlabel('State',fontsize=15);
ax.set_ylabel('Value',fontsize=15);
sns.set_style('white');
sns.despine();

# TD-error
df_wide = pd.DataFrame(D.T)

fig, ax = plt.subplots(1,1,figsize=(9,4))
sns.lineplot(data=df_wide, legend=True, palette='Greens', markers=True, dashes=False)
ax.legend(labels=list(np.arange(params['n_states'])+1))
ax.axvline(x=params['n_states']-1, color='green',linewidth=4)
ax.set_xticks(np.arange(params['n_states']))
labels = [str(i) for i in np.arange(params['n_states'])+1]
labels[-1] = 'R'
ax.set_xticklabels(labels)
ax.set_xlabel('State',fontsize=15);
ax.set_ylabel('Temporal-Difference error',fontsize=15);
sns.set_style('white');
sns.despine();

env.visualize()
# Out:
# Green is the goal state...

# %% [markdown]
# ## Bonus
# Choose one of the model-free control algorithms in class and implement it for the single track environment. How are the predictions of the model going to be different, and why? (hint: think about what happens once we introduce actions)
#
# - trying SARSA - on-policy TD control where an agent commits to the same policy and evaluates actions

# %%
class SARSA(object):
  """Class for the TDRL reward prediction algorithm. 

  Parameters
  ----------

  alpha : float, range (0, 1)
      Learning rate.

  gamma : float, range (0, 1)
      Discount factor.

  """

  def __init__(self, env, alpha, gamma, v_init = False):

    self.a = alpha 
    self.g = gamma

    # initialize values
    if v_init: # check if initial values were provided 
      self.v = np.ones((env.n_states, ))*v_init     
    else:   
      self.v = np.zeros((env.n_states, ))

    # initialize td-errors
    self.d = np.zeros((env.n_states, ))

  def update(self, current_state, new_state, reward, verbose=False):

    td_error = reward + self.g * self.v[new_state-1] - self.v[current_state-1]

    print('delta: ' + str(td_error))

    self.d[current_state] = td_error
    self.v[current_state-1] = self.v[current_state-1] + self.a * td_error

    if verbose == True: 
      print(self.v)

# %% [markdown]
# https://www.geeksforgeeks.org/sarsa-reinforcement-learning/
